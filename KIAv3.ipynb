# %% [markdown]
# <a href="https://colab.research.google.com/github/badmsconfig/DZ_11/blob/main/KIAv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code

# %%
# !pip  install  tiktoken==0.4.0  langchain==0.0.231 openai==0.27.8 faiss-cpu==1.7.4 gspread oauth2client nltk pydantic==1.10.8
# Out:
# Collecting tiktoken==0.4.0
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.9 MB/s eta 0:00:00
# Collecting langchain==0.0.231
#   Downloading langchain-0.0.231-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.9 MB/s eta 0:00:00
# Collecting openai==0.27.8
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 10.0 MB/s eta 0:00:00
# Collecting faiss-cpu==1.7.4
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 76.8 MB/s eta 0:00:00
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting pydantic==1.10.8
#   Downloading pydantic-1.10.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.4.0) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.4.0) (2.31.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (3.8.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain==0.0.231)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langchainplus-sdk<0.0.21,>=0.0.20 (from langchain==0.0.231)
#   Downloading langchainplus_sdk-0.0.20-py3-none-any.whl (25 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (2.8.7)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (1.23.5)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain==0.0.231)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.231) (8.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.8) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==1.10.8) (4.5.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (from gspread) (2.17.3)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.231) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.231)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.231)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.4.0) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.231) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth->gspread) (5.3.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.231) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.231)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: faiss-cpu, pydantic, mypy-extensions, marshmallow, typing-inspect, tiktoken, openapi-schema-pydantic, langchainplus-sdk, openai, dataclasses-json, langchain
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# Successfully installed dataclasses-json-0.5.14 faiss-cpu-1.7.4 langchain-0.0.231 langchainplus-sdk-0.0.20 marshmallow-3.20.1 mypy-extensions-1.0.0 openai-0.27.8 openapi-schema-pydantic-1.2.4 pydantic-1.10.8 tiktoken-0.4.0 typing-inspect-0.9.0

# %%
import gdown
from langchain.llms import OpenAI
from langchain.docstore.document import Document
import requests
#database
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
#from langchain.document_loaders import TextLoader

from langchain.prompts import PromptTemplate
import pathlib
import subprocess
import tempfile
import ipywidgets as widgets
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import re
import getpass
import os
import openai
import tiktoken

class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'


HISTORY = []

# %%
MODEL_GPT_3_5_TURBO_16K = ['gpt-3.5-turbo-16k', 0.003, 0.004]
MODEL_GPT_3_5_TURBO = ['gpt-3.5-turbo', 0.0015, 0.002]  # 4,097 tokens
MODEL_GPT_3_5_TURBO_INSTRUCT = ['gpt-3.5-turbo-instruct', 0.0015, 0.002]  # 4,097 tokens
MODEL_GPT_4 = ['gpt-4', 0.03, 0.06]  # 8,192 tokens
MODEL_GPT_4t = ['gpt-4-1106-preview', 0.03, 0.06]  # 8,192 tokens

SELECT_MODEL_GPT = MODEL_GPT_4t

# %%
openai_key = getpass.getpass("OpenAI API Key:")
os.environ["OPENAI_API_KEY"] = openai_key
openai.api_key = openai_key
# Out:
# OpenAI API Key:··········

# %%
def insert_newlines(textstr: str, max_len: int = 170) -> str:
    words = textstr.split()
    lines = []
    current_line = ""
    for word in words:
        if len(current_line + " " + word) > max_len:
            lines.append(current_line)
            current_line = ""
        current_line += " " + word
    lines.append(current_line)
    return "\n".join(lines)

# %%
# функция для загрузки документа по ссылке из гугл драйв
def load_document_text(url: str) -> str:
    # Extract the document ID from the URL
    match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
    if match_ is None:
        raise ValueError('Invalid Google Docs URL')
    doc_id = match_.group(1)

    # Download the document as plain text
    response = requests.get(f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
    response.raise_for_status()
    text = response.text

    return text

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter
import re

def load_file_knowledge(file_path: str) -> str:
    # Чтение текстового файла
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    headers_to_split_on = [
        ("#", "router"),
        ("##", "theme"),
        ("###", "Header3"),
        ("####", "Header4"),
    ]

    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
    md_header_splits = markdown_splitter.split_text(text)

    # Предполагается, что FAISS и OpenAIEmbeddings были импортированы или определены где-то выше
    vectordateBase = FAISS.from_documents(md_header_splits, OpenAIEmbeddings())

    return vectordateBase

# %%
knowledge_base = load_file_knowledge('database.md')

# %%
def _summarize_topic( dialog):
        messages = [
            {"role": "system",
             "content": "Ты - ассистент консультанта, основанный на AI. Ты умеешь профессионально суммаризировать присланные тебе диалоги консультанта и клиента. Твоя задача - суммаризировать диалог, который тебе пришел."},
            {"role": "user",
             "content": "Суммаризируй следующий диалог консультанта и клиента: " + " ".join(dialog)}
        ]

        completion = openai.ChatCompletion.create(
            model=SELECT_MODEL_GPT[0],
            messages=messages,
            temperature=0.1,  # Используем более низкую температуру для более определенной суммаризации
            max_tokens=1000  # Ограничиваем количество токенов для суммаризации
        )

        return completion.choices[0].message.content



def answer_index(topic, temp=0.1, top_similar_documents=5):
        summarize_text = ''
        HISTORY = '' # ОТКЛЮЧАЕТ САММОРИЗАЦИЮ! ЕСТЬ НУЖНО ЕЕ ВКЛЮЧИТЬ ТОГДА ЗАКОМЕНТИРУЙ
        if len(HISTORY) > 0:
            summarize_text = "Вот краткий обзор предыдущего диалога: " + _summarize_topic(
                [q + ' ' + (a if a is not None else '') for q, a in HISTORY])
            print(f'САММАРИ \n=== {summarize_text} \n')

        # Добавляем явное разделение между историей диалога и текущим вопросом
        input_text = summarize_text + "\n\nТекущий вопрос: " + topic

        docs = knowledge_base.similarity_search_with_score(topic, k=top_similar_documents)
        responses = []
        for i, (doc, score) in enumerate(docs):
            if score < 1: # ТУТ ТЫ МОЖЕШЬ УПРАВЛЯТЬ праметром Л2 для чанков. 0..1
                content = doc.page_content
                response = f'\n=====================Отрывок документа №{i + 1}=====================\n{content}\n'
                print(f'\n=====================Отрывок документа №{i + 1}=====================\n')
                print(f'=== score = {score}  Metadata документа ------------ {doc.metadata}')
                print(f'\n{content}\n')
                responses.append(response)


        messages = [
            {"role": "system", "content": prompt},
            {"role": "user",
             "content": f"Документ с информацией для ответа пользователю: {responses}\n\nВопрос клиента: \n{input_text}"}
        ]

        completion = openai.ChatCompletion.create(
            model=SELECT_MODEL_GPT[0],
            messages=messages,
            temperature=temp
        )

        answer = completion.choices[0].message.content

        # Добавляем вопрос пользователя и ответ системы в историю
        if len(HISTORY) > 0:
            HISTORY.append((topic, answer if answer is not None else ''))

        return insert_newlines(answer)  # возвращает ответ

# %%
def run_dialog(system_doc_url, knowledge_base_url):

    while True:
        user_question = input('\nКлиент: ')
        if ((user_question.lower() == 'stop') or (user_question.lower() == 'стоп')):
            break
        answer = answer_index(user_question)
        print('\nМенеджер: ', answer+'\n\n')

    return

# %%
# Промпт моделей машин
prompt = load_document_text('https://docs.google.com/document/d/1i8HA7cX4Ut-tb9rf8wOgERU7lLe66xJYscizGtSSJl0')

# %%
temperature=0.3
verbose=0
#HISTORY = [] # Убери решетку если нужно обновлять историю диалогов после запуска, если не нужно обновлять то оставь так

run_dialog(prompt, knowledge_base)
# Out:
# Клиент: "Здравствуйте подскажите пожалуйста мне с банка пришло смс о первоначальном одобрение Я оставлял заявку на покупку машины"
#
# =====================Отрывок документа №1=====================
#
# === score = 0.28271329402923584  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases187'}
#
# Информацию о покупке автомобиля в рассрочку или кредит под такси без первоначального взноса можно получить у официальных дилерских центров и банков-партнеров.
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.30932557582855225  Metadata документа ------------ {'router': 'apps', 'theme': 'Проблема с активацией автомобиля в приложении Mobikey'}
#
# Если автомобиль не отображается в приложении mobikey, необходимо направить обращение на электронную почту mobikey@hyundai.ru, указав следующую информацию: имя и фамилию владельца учетной записи, телефон, указанный дилеру для регистрации, VIN номер автомобиля, дилерский центр, который производил активацию, описание ситуации, если дилер отказал в активации, дату обращения в дилерский центр, и скрин приложения с ошибкой, если ошибка присутствует.
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.3100452423095703  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases389'}
#
# Обращение за подтверждающим документом собственности авто рекомендуется направлять в дилерский центр, где был приобретен автомобиль. Если дилерский центр закрыт, следует
# оставить обращение ответственным сотрудникам КИА, указав фамилию, имя, номер телефона, e-mail, подробное описание ситуации, модель автомобиля, VIN номер, информацию о
# дилерском центре и предоставленную информацию.
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.31238889694213867  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases266'}
#
# Граждане РБ, официально работающие в Москве, могут взять машину в кредит. Информация о кредитных программах, условиях и процедуре оформления доступна на официальном
# сайте www.kia.ru в разделе «Выбор и покупка» «Кредитование». При возникновении вопросов помощь предоставляют специалисты кредитного отдела или отдела продаж официального
# дилера Kia. Контакты дилеров доступны на сайте по ссылке: https://www.kia.ru/dealers/.
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.31490370631217957  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases0'}
#
# Вопросы по кредитованию для покупки машины следует обсуждать с дилером. Список и контакты всех официальных дилеров доступны на сайте https://www.kia.ru/dealers/ в разделе «Дилеры».
#
#
# Менеджер:   Здравствуйте! Для того чтобы уточнить информацию о первоначальном одобрении кредита на покупку автомобиля, вам следует связаться с официальным дилерским центром, где вы
#  оставляли заявку, или напрямую с банком, который отправил вам сообщение. Если у вас возникнут дополнительные вопросы по кредитованию или покупке автомобиля, вы можете
#  обратиться к специалистам кредитного отдела или отдела продаж официального дилера Kia. Контакты дилеров доступны на сайте [KIA](https://www.kia.ru/dealers/).
#
#
#
# Клиент: Хочу взять киа селтос в кредит какие условия и цены
#
# =====================Отрывок документа №1=====================
#
# === score = 0.2131986767053604  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases180'}
#
# Условия кредита и цены на автомобиль Kia Seltos можно узнать, перейдя по ссылке https://www.kia.ru/marketplace/all_cars/ , выбрав интересующий автомобиль и нажав на "Рассчитайте кредит". Дополнительные опции для оформления кредита следует уточнить в дилерском центре Kia. Контакты всех официальных дилеров доступны на сайте по ссылке https://www.kia.ru/dealers/
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.2598050534725189  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases266'}
#
# Граждане РБ, официально работающие в Москве, могут взять машину в кредит. Информация о кредитных программах, условиях и процедуре оформления доступна на официальном
# сайте www.kia.ru в разделе «Выбор и покупка» «Кредитование». При возникновении вопросов помощь предоставляют специалисты кредитного отдела или отдела продаж официального
# дилера Kia. Контакты дилеров доступны на сайте по ссылке: https://www.kia.ru/dealers/.
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.26693159341812134  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases187'}
#
# Информацию о покупке автомобиля в рассрочку или кредит под такси без первоначального взноса можно получить у официальных дилерских центров и банков-партнеров.
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.2685346007347107  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases68'}
#
# Услуга KIA Flex доступна в Москве и Санкт-Петербурге. Аренда автомобиля Киа Сэлтос возможна с указанными датами. Путешествие возможно только по территории Российской
# Федерации. Выезд за границу требует дополнительного согласования с дилером и получения соответствующего документа. Дополнительная информация доступна на сайте в разделе
# «Авто по подписке».
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.2689319849014282  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases304'}
#
# Граждане СНГ могут приобрести автомобиль в кредит, обратившись в официальные дилерские центры Kia. Контакты дилеров доступны на сайте: https://www.kia.ru/dealers/.
#
#
# Менеджер:   Условия кредита и цены на автомобиль Kia Seltos можно узнать, перейдя по ссылке [КИА Маркетплейс](https://www.kia.ru/marketplace/all_cars/), выбрав интересующий
#  автомобиль и нажав на "Рассчитайте кредит". Для получения информации о дополнительных опциях кредитования рекомендую обратиться в дилерский центр Kia. Контакты всех
#  официальных дилеров доступны на сайте по [ссылке](https://www.kia.ru/dealers/).
#
#
#
# Клиент: Цены указанные на сайте реальные?
#
# =====================Отрывок документа №1=====================
#
# === score = 0.26749932765960693  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases354'}
#
# Цены на автомобили, указанные на сайте, несут информационный характер. Окончательную стоимость необходимо уточнять у официального дилера. Приобрести автомобиль через официальный сайт невозможно.
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.2808856666088104  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases318'}
#
# На официальном сайте указана максимальная цена перепродажи автомобилей и для предлагаемых изготовителем комплектаций. Конечная сумма сделки может варьироваться в зависимости от дополнительного оборудования и работ.
# Указанные цены на сайте могут отличаться от действительных цен дилеров. Для получения актуальных цен, обращайтесь к дилерам.
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.2883493900299072  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases55'}
#
# Цены, указанные на официальном сайте Kia, носят информационный характер и могут отличаться от действительных цен дилеров Kia. Точную стоимость автомобиля можно уточнить
# в дилерском центре Kia. Контакты всех официальных дилеров доступны на сайте https://www.kia.ru/dealers/ в разделе «Дилеры».
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.2886013984680176  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases57'}
#
# Цены на автомобили, указанные при онлайн-бронировании на сайте www.kia.ru, носят информационный характер и могут отличаться от действительных цен дилеров KIA. Для
# получения точной информации рекомендуется обращаться к официальным дилерам. Контакты всех официальных дилеров доступны на сайте https://www.kia.ru/dealers/ в разделе «Дилеры».
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.29589954018592834  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases53'}
#
# Цены на автомобили Kia, указанные на сайте, могут отличаться от действительных цен у дилеров. Дилеры могут добавлять дополнительное
# оборудование, что влияет на конечную стоимость автомобиля. При оформлении заказа на приобретение автомобиля из поставки можно приобрести автомобиль без дополнительного
# оборудования.
#
#
# Менеджер:   Цены на автомобили, указанные на официальном сайте Kia, носят информационный характер и могут отличаться от действительных цен дилеров Kia. Для получения актуальных цен
#  рекомендуется обращаться к официальным дилерам. Контакты всех официальных дилеров доступны на сайте в разделе "Дилеры". Вот ссылка для поиска дилера:
#  [https://www.kia.ru/dealers/](https://www.kia.ru/dealers/).
#
#
#
# Клиент: Kia XCeed есть такие авто
#
# =====================Отрывок документа №1=====================
#
# === score = 0.22342851758003235  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases360'}
#
# Новые модели Kia XCeed не поставляются. Информацию о наличии автомобилей Kia и вариантах их комплектаций можно узнать на официальном сайте в разделах «Комплектации и
# цены» и «Купить автомобиль». Все сведения на сайте носят информационный характер. Для получения подробной консультации рекомендуется обратиться к специалистам отдела продаж официального дилера Kia. Контакты дилеров доступны на сайте: https://www.kia.ru/dealers/.
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.25931012630462646  Metadata документа ------------ {'router': 'models', 'theme': 'Kia Ceed 2022'}
#
# Kia Ceed 2022 - https://www.kia.ru/models/ceed/desc/
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.2664903998374939  Metadata документа ------------ {'router': 'models', 'theme': 'Kia Ceed SW 2022'}
#
# Kia Ceed SW 2022 - https://www.kia.ru/models/ceed_sw/desc/
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.2672586739063263  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases278'}
#
# Модели автомобилей Kia Ceed CD SW PE и Ceed CD PE производятся в Словакии и Российской Федерации (SKD). Информацию о моделях и вариантах комплектаций можно найти на сайте https://www.kia.ru/models/. Наличие автомобилей у дилеров можно уточнить по ссылке: https://www.kia.ru/buy/cars/.
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.2750694155693054  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases223'}
#
# Модель автомобиля Киа Xceed может быть недоступна на официальном сайте, но дилеры могут продавать автомобили на основе наличия на своем складе. Поставка автомобилей под заказ в настоящее время не осуществляется. Киа Россия и СНГ отвечает за оптовые продажи автомобилей Kia на российском рынке, но не комментирует вопросы, связанные с деталями производства.
#
#
# Менеджер:   На данный момент новые модели Kia XCeed не поставляются. Однако дилеры могут иметь в наличии автомобили Kia XCeed на своих складах. Чтобы узнать о наличии и вариантах
#  комплектаций, рекомендуется посетить официальный сайт Kia в разделах «Комплектации и цены» и «Купить автомобиль». Для получения подробной консультации и актуальной
#  информации о наличии автомобилей у дилеров, пожалуйста, обратитесь к специалистам отдела продаж официального дилера Kia. Контакты дилеров доступны на сайте:
#  [https://www.kia.ru/dealers/](https://www.kia.ru/dealers/).
#
#
#
# Клиент: "Будет ли новая поставка автомобилей 2023 года? "
#
# =====================Отрывок документа №1=====================
#
# === score = 0.3058820366859436  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases339'}
#
# Поставка автомобилей, которых нет в наличии, временно приостановлена.
#
#
# =====================Отрывок документа №2=====================
#
# === score = 0.3085678219795227  Metadata документа ------------ {'router': 'sales', 'theme': 'sales_purchases414'}
#
# Автомобили Kia K5 2023 года выпуска доступны для покупки. Гарантийное обслуживание предоставляется для автомобилей, ввезенных официальным дистрибьютором Kia в России -
# ООО «Киа Россия и СНГ». Автомобили, приобретенные за пределами РФ и поставленные на учет в России, не подлежат гарантийному обслуживанию.
#
#
# =====================Отрывок документа №3=====================
#
# === score = 0.3105129301548004  Metadata документа ------------ {'router': 'tech', 'theme': 'tech321'}
#
# Возможность обновления головного устройства автомобиля Сорренто 2023 года можно уточнить в личном кабинете на официальном сайте или при обращении к официальному дилеру.
#
#
# =====================Отрывок документа №4=====================
#
# === score = 0.3122355043888092  Metadata документа ------------ {'router': 'service', 'theme': 'Влияние переноса технического обслуживания на гарантию автомобиля'}
#
# Если техническое обслуживание автомобиля переносится на более позднюю дату, это может повлиять на гарантию.
#
#
# =====================Отрывок документа №5=====================
#
# === score = 0.3157074451446533  Metadata документа ------------ {'router': 'service', 'theme': 'Kia Flex / Аренда автомобилей Kia по подписке', 'Header3': 'Могу ли я выбрать автомобиль другой модели, не из представленного списка?'}
#
# Могу ли я выбрать автомобиль другой модели, не из представленного списка? Обратитесь к дилеру для заявки на автомобиль другой модели. Тариф обсуждается с дилером индивидуально.
#
#
# Менеджер:   Поставка автомобилей, которых нет в наличии, временно приостановлена. Если вы заинтересованы в приобретении автомобиля Kia, рекомендую обратиться к официальному дилеру
#  для получения актуальной информации о наличии конкретных моделей и возможных сроках поставки.
